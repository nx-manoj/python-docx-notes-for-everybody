# %% [markdown]
# ### Python oops explained simply

# %% [markdown]
# Did you know : python also uses oops...but where ?

# %%
#Let's say 
name = 'Manoj'

# %% [markdown]
# You see that i create a name varaible and stored 'Manoj' \
# So what's the data type of name ???..It's String right ?

# %%
print(type(name))
# Out:
# <class 'str'>

# %% [markdown]
# Hey you see that when i code `type(name)` it shows the output as `class 'str'`

# %%
print(type(list(range(1,11))))
# Out:
# <class 'list'>

# %% [markdown]
# *and list is also a Class 👀....*

# %% [markdown]
# ### So what you learned from this ?
# ### You know that python have built in classes too...

# %% [markdown]
# ## why oops ?
#
# because we can take objects from the real world to create some code...
# (or)
# you may don't need to create variables again and again \
# confusing ??

# %%
## okay let's see python built on classes 

name = 'Manoj'
print(name.lower())
# Out:
# manoj

# %% [markdown]
# Here `lower()` is an method of class `str`

# %%
print(type(name.lower()))
# Out:
# <class 'str'>

# %% [markdown]
# what the hell is method ? just simply fix in mind that method is just a fucntion inside a class
#
# method =  A function inside a class

# %% [markdown]
# #### str is only the python's built in class ?
# Answer : No

# %%
print(type(10))
print(type(10.5))
print(type('Deepu'))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>

# %% [markdown]
# Woahhh this are all just built in class methods...
# So you got some idea ??

# %% [markdown]
# #### What is class
# A class is a blueprint to create an object

# %%
## without class
student_name = 'Manoj'
student_age = 19

# %% [markdown]
# What if we have 100 student's data...😭 \
# you will create each student with create 100's of varaibles...?\
# That's why class is there

# %%
## With class
class Student:  ##class 
    pass

# %% [markdown]
# #### Here `Student` is a blueprint and we can create objects from it

# %%
s1 = Student()  #s1 is an object of class student..

# %%
print(type(s1))
# Out:
# <class '__main__.Student'>

# %% [markdown]
# you see that `s1` is a instance or object (whatever) of class....
